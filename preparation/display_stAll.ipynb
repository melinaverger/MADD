# %%
"""
Created on: Fri. 5 Aug. 2022
Updated on: Tue. 9 Aug. 2022
Updated on: Tue. 23 Aug. 2022
Updated on: Mon. 29 Aug. 2022
Updated on: Wed. 31 Aug. 2022
Updated on: Fri. 30 Sep. 2022
Updated on: Wed. 12 Oct. 2022
Updated on: Fri. 6 Jan. 2023
Author: Mélina Verger

Display stAll.
"""

# For data manipulation
import pandas as pd

# %%
stAll = pd.read_csv("../data/studentAll.csv")

# %%
stAll
# Out:
#       code_module code_presentation  id_student gender               region  \
# 0             AAA             2013J       11391      M  East Anglian Region
# 1             AAA             2013J       11391      M  East Anglian Region
# 2             AAA             2013J       11391      M  East Anglian Region
# 3             AAA             2013J       11391      M  East Anglian Region
# 4             AAA             2013J       11391      M  East Anglian Region
# ...           ...               ...         ...    ...                  ...
# 26584         GGG             2014J     2620947      F             Scotland
# 26585         GGG             2014J     2645731      F  East Anglian Region
# 26586         GGG             2014J     2648187      F         South Region
# 26587         GGG             2014J     2679821      F    South East Region
# 26588         GGG             2014J     2684003      F     Yorkshire Region
#
# ...

# %%
len(stAll["id_student"].unique())
# Out:
# 23344

# %%
stAll.isna().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1030
# age_band                   0
# disability                 0
# num_of_prev_attempts       0
# studied_credits            0
# sum_click                  0
# weighted_score             0
# final_result               0
# dtype: int64
